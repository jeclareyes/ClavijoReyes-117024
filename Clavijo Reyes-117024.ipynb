# %% [markdown]
# Sin utilizar el comando abs, escribir un programa que calcule e imprima el valor absoluto de cualquier número (sea entero o decimal).

# %%
x =int(input("Digite un número "))
print("Su numero es: ",x)

if x>=0: print("Su valor absoluto es: ",x)
if x<0: print("Su valor absoluto es: ",-1*x)    #Condición que devuelve un nú-
                                                #mero negativo en uno positivo
# Out:
# Digite un número -10
# Su numero es:  -10
# Su valor absoluto es:  10

# %% [markdown]
# Leer un número entero y escribirlo en reversa. Por ejemplo, 461975 será 579164. No utilizar comandos de ordenamiento.

# %%
#Este código invierte todos los dígitos de un número
L=[]
nn=[]
n = int(input("Ingrese un numero entero de cualquier cantidad de cifras\
 para ser invertido: "))
print('El número invertido es: ' )
if n<0:
    n= n*(-1)
    while n>0:              #Ciclo que permite sacar dígito por dígito del 
        L.append(n%10)      #número introducido, dado a que el ciclo opera de
        n=int(n/10)         #derecha a izquierda, el número queda guardado en
                            #una lista de manera invertida
    for i in L:
       print(i,end='')    
       
else:
    while n>0:              #Ciclo que permite imprimir cada elemento de la
        L.append(n%10)      #lista sin espacios
        n=int(n/10)


    for i in L:
        print(i, end="")

# %% [markdown]
# Leer un número entero de 3 dígitos y determinar si contiene el dígito 8.

# %%
x = int(input("Ingrese un número de tres dígitos"))
if x<0: x=x*-1
if x%10 == 8:                               #Operador que descompone el último
    print("tiene el digito 8")              #número
elif int(x/10)%10 ==8:                      #operador que descompone el 
        print("tiene el digito 8")          #penúltimo número
elif int(x/100)%10 ==8:                     #operador que descompone el primer
        print("tiene el digito 8")          #número
else: print("No tiene el digito 8")         #el == me permite conocer si el
                                            #numero introducido contiene el
                                            #Dígito

# %% [markdown]
# Leer un número entero positivo y determinar la suma de sus dígitos pares. Por ejemplo, en el número 124, los dígitos pares son el 2 y el 4 y su suma vale 6.

# %%
x=int(input("Ingrese un numero para calcular la suma de sus dígitos pares: "))

p=[]

# (x%10) es el digito

while x>0:
    if (x%10)%2==0:                 #Discriminante del número par que si se
        p.append(x%10)              #Cumple lo agregará a un lista

# %% [markdown]
# Leer un número entero y determinar el número de cincos que están consecutivos en un número. Por ejemplo, en
# 5512355551 hay 6 cincos consecutivos. Ahora, en 234555234512 solo hay 3 cincos consecutivos.

# %%
ont=0
L=[]
M=[1]
x=int(input("ingrese un numero: "))
x2=x

while x>0:                  #Este ciclo permite convertir el número en lista
        L.append(x%10)      
        x=int(x/10)
        
L=L[::-1]                   #Este código imprime el número en orden
L.append(0)                 #Esto corrige que la iteración se salga del rango
L.insert(0,0)               #Esto corrige el contador cuando el número 
                            #comience en 5


   
for i in range(0,(len(L)-1)):
    
    if L[i]==5 and L[i+1]==5:       #El código evaluará en orden el elemento i
        cont+=1                     #y el elemento i+1 sumando al contador 1,
                                    #cuando se encuentren dos cincos consec.
    
    if L[i]!=5 and L[i+1]==5 and L[i+2]==5:       
             cont+=1                       
                                    #del mismo modo cuando i sea diferente de 5
                                    #pero i+1 sea igual a 5 se sumará 1 al cont
                                    #para incluir al primer 5 de cada grupo
    else:                           #consecutivo
        i+=1
        

print('El número ',x2, 'tiene ',cont, 'cincos consecutivos')

# %% [markdown]
# Leer un número entero y determinar si la suma de sus dígitos es un número de Fibonacci.

# %%
Num = int(input('Ingrese un numero entero : '))

L=[1,1]                             #Lista de la serie de Fibonacci, (Se 
                                    #comienza con los dos primeros números)

while L[-1]<Num:                    
   
    
    for i in range(0,Num):          #Iteración que saca la serie de Fibonacci
    
            C=L[i]+L[i+1]
            L.append(C)
    

    
if Num in L:            #Comando que permite evaluar si el número introducido
                        #se encuentra en la serie de fibonacci
    print('El número ',Num ,'está en la serie de Fibonacci')
  
else:
    print('El número ',Num ,' no está en la serie de Fibonacci')

# %% [markdown]
# Leer un número entero positivo y determine si existen en el número dígitos repetidos. Reporte cuales son los dígitos repetidos.

# %%
L=[]
x= int(input('Digite un numero: '))   
while x>0:
    n=x%10              #por medio del % se descompone el número y cada
    L.append(n)         #dígito se va agregando a una lista
    x= int(x/10)
Rep = []
for i in L:
    C = 0
    if i not in Rep:
        for j in range(0,len(L)):
            if (i - L[j]) == 0:         #operación que discrimina si dos
                C += 1                  #número son iguales, si pasa esto, se
                if C == 2:              #se agrega más 1 al contador
                    print('El',i,'se repite.') #si el contador llega a 2 
                                               #significa que hay un dígito
                                               #repetido y este será agregado
                                               #a otra lista que después será
                                               #impresa, informando qué
                                               #números se repiten
                    break
        Rep.append(i)

# %% [markdown]
# Iterar a través de los primeros cien enteros positivos, buscando los múltiplos de 3 e imprimiendo y almacenándolos en una lista hasta encontrar los primeros 15 de ellos. Una vez encontrados, continuar iterando en busca de los múltiplos de 4 y almacenarlos en otra lista.

# %%
M3=[]
M4=[]
L=[]
cont1=0
cont2=0

for i in range(0,101):
    if i % 3  == 0 :        # % permite conocer cuales son los números por 3
                            #su residuo es 0, por tanto si estos números 
                            #cumplen con la condición serán almacenados en la
                            #lista L
        
        cont1 += 1          #Cuando la longitud de la lista sea mayor a 15
        M3.append(i)        #Se romperá el ciclo for, y se iniciará otro
    if cont1  == 15 :       #con la condición de % para los múltiplos de 4
        break               #y del mismo modo se almacenarán en la lista
    
for i in range(M3[14],101):
    if i % 4 == 0 :
     
        cont2 += 1
        M4.append(i)

    
print("los primeros quince múltiplos del 3 son: ", M3)
print("los múltiplos de cuatro a partir del ", M3[-1], 'son: ', M4)

# %% [markdown]
# Hacer un programa que lea las coordenadas (x1,y1,r1) y (x2,y2,r2) que corresponden al centro y al radio de dos círculos.
# Lea un punto de coordenadas (a,b). Determina si (a,b) está contenido: a) dentro del círculo 1; b) dentro del círculo 2;
# c) dentro de ambos círculos; d) fuera de ambos círculos. Recordemos que el círculo es el lugar geométrico de los puntos
# del plano cuya distancia a otro punto fijo, llamado centro, es menor o igual que una cantidad constante, llamada radio.

# %%
print("Este programa ayudará a determinar si un punto evaluado en R2 está\
 contenido o no en dos circunferencias dadas por el usuario.")

#Se le pide al usuario que escriba las coordenadas de los círculos y sus radios

print('Escriba las coordenadas del circulo 1 y el tamaño de su radio: ') 
x1=int(input(' Coordenada en x: '))
y1= int(input(' Coordenada en y: '))
r1=int(input('Tamaño del radio r: '))

print('Escriba las coordenadas del circulo 2 y el tamaño de su radio:') 
x2=int(input('Coordenada en x: '))
y2= int(input('Coordenada en y: '))
r2=int(input('Tamaño del radio r: '))

#Se le pide al usuario que escriba un coordenada cualquier para evaluarla 
#De acuerdo a los parámetros dado en el enunciado

a=int(input('Escriba una coordenada en x: ' ))
b=int(input('Escriba una coordenada en y: ' ))

#Se usan las condiciones para saber en que posición está el punto. Se usa
#la fórmula de la circunferencia para saber si el punto está contenido
#y se aplican los condicionales para saber si está contenido en ambos, en uno
#o en ninguno

if (a-x1)**2+(b-y1)**2 < r1**2 and (a-x2)**2+(b-y2)**2 < r2**2: 
    print('La coordenada está dentro del círculo 1 y 2')
    
elif (a-x1)**2+(b-y1)**2 < r1**2:
    print('La coordenada está dentro del círculo 1')    
    
elif (a-x2)**2+(b-y2)**2 < r2**2:
    print('La coordenada está dentro del círculo 2')    

if (a-x1)**2+(b-y1)**2 >= r1**2 and (a-x2)**2+(b-y2)**2 >= r2**2: 
    print('la coordenada no está contenida en ningún circulo')

# %% [markdown]
# Sin utilizar el método .upper() para cadenas, escribir un programa que lea una cadena de texto y la imprima en
# mayúscula. Tenga en cuenta que el programa debe aceptar las letras con tilde, la ñ y la ü.

# %%
print("""El siguiente programa leerá una palabra que usted escriba en 
      minúsculas y pasará la misma a sus respectivas mayúsculas (también 
      funciona para frases""")

a='qwertyuiopasdfghjklñzxcvbnmáéíóúü !"#$%&/()=?¡*_:;,0123456789QWERTYUIOPASD\
FGHJKLÑZXCVBNM'
b='QWERTYUIOPASDFGHJKLÑZXCVBNMÁÉÍÓÚÜ !"#$%&/()=?¡*_:;,0123456789QWERTYUIOPASD\
FGHJKLÑZXCVBNM'

#Se realiza un diccionario con todos los caracteres posibles del español para
#hacer un código que haga la transición entre uno y otro por medio de los
#índices

pal =str(input("Escriba una palabra en minúsculas y en español: "))
ubi=[]
Mayus=[]

for i in range(0,len(pal)):
    n = a.find(pal[i])
    ubi.append(n)

#Aquí se extrae la ubicación de cada caracter encontrado en la cadena a y se
#almacenan en una lista llamada ubi
    
print( 'la palabra en mayúsculas es:')
for i in range(0,len(ubi)):
    print(b[ubi[i]], end='')
    
#Finalmente se imprimen los caracteres con respecto al índices de la lista b
#para obtener la palabra en mayúsculas

# %% [markdown]
# Escribir un programa que reciba una cadena de texto y reporte:
# a) cuántas letras vocales en mayúscula se entraron;
# b) cuántas letras con tilde se entraron (minúsculas y mayúsculas);
# c) cuántos dígitos se entraron,
# d) cuántos espacios se entraron;
# e) cuántas palabras reservadas se entraron.

# %%
import keyword  #Se importa la libreria de las keyword para después evaluar si
                #en la cadena introducida se encuentra alguna de ellas

word =input("Escriba una palabra: ")

#Se crea una cadena con las vocales mayúsculas y despúes se evalúa índice por
#índice en búsqueda de una vocal mayúscula agregándose a una lista para después
#contar su longitud

VM="AEIOUÁÉÍÓÚ"
L1=[]
for i in range(0,len(word)):
    if word[i] in VM:
        L1.append(word[i])

print("Hay ", len(L1), "vocales mayúsculas")

#Se crea una cadena con las vocales tildadas y despúes se evalúa índice por
#índice en búsqueda de una vocal tildada agregándose a una lista para después
#contar su longitud

VMT= 'áéíóúÁÉÍÓÚ'
L2=[]
for i in range(0,len(word)):
    if word[i] in VMT:
        L2.append(word[i])

print('Hay', len(L2), 'vocales con tilde')

#Se crea una cadena con los números dígitos y despúes se evalúa índice por
#índice en búsqueda de un dígito a una lista para después
#contar su longitud

Dig= "0123456789"
L3=[]

for i in range(0,len(word)):
    if word[i] in Dig:
        L3.append(word[i])

print('Hay ', len(L3), 'dígitos')

#Se crea una cadena con espacio para evaluar índice por índice si hay alguno
#en la cadena, se agrega a la lista una vez encontrado uno, y se cuenta la
#longitud de la lista creada

Esp= ' '
L4=[]        
        
for i in range(0,len(word)):
    if word[i] in Esp:
        L4.append(word[i])

print('Hay ', len(L4), 'espacios')   


#Se parte la cadena para facilitar a través de las listas el encontrar una
#keyword, esto es posible usando "keyword.kwlist" el cual contiene todas 
#las keywords, una vez encontrada una se agrega a la lista, se cuenta la
#longitud y se imprima cuales son las encontradas

L5= word.split()
L6=[]

for i in range(0,len(L5)):
    if L5[i] in keyword.kwlist:
        L6.append(L5[i])
        
print(L6, 'son keywords contenidas en la palabra que digitó')

# %% [markdown]
# Hacer un programa que lea dos palabras (podrían estar en mayúscula o minúscula) y determine cual está primero en el diccionario. El programa debe soportar letras con tilde, la ü y la ñ.

# %%
#Se exije que el usuario introduzca dos palabras

a=str(input("Escriba una palabra: "))
b=str(input("Escriba otra palabra: "))


#y se pasan a minúsculas para mayor comodidad a la hora de la comparación

a= a.lower()
b= b.lower()

c= list(a)
d= list(b)

#Se crean dos listas, una con las vocales normales y la otra con tildes 
#esto permitirá al código convertir las vocales tildadas en sin tildes
#para facilitar la comparación

U=['á','é','í','ó','ú','ü']
V=['a','e','i','o','u','u']

#El programa irá de índice en índice chequeando si este posee á,é,í,ó o ú
#caso a acontecer se reemplazará por su homónima sin tilde

for i in range(0,len(c)):
    for j in range(0,len(U)):
        
        if c[i]== U[j]:
            c[i]=V[j]
            
for i in range(0,len(d)):
    for j in range(0,len(U)):
        
        if d[i]== U[j]:
            d[i]=V[j]
  

#Lo siguiente se hará para definir el rango máximo a evaluar ya que no todas
#las palabras tienen la misma cantidad de caracteres, en este caso siempre
#se tomará la palabra de menor longitud 
    
            
Z=0
if len(c)==len(d): Z=len(d)
if len(c)>len(d): Z=len(d)
else: Z=len(c)
       
#El siguiente ciclo comparará los índices de cada palabra, y se establecerán
#condiciones para saber qué palabra está primero en el diccionario   
for i in range(Z):
    if c[i]>d[i]:
            print(b, ' está primero en el diccionario')
            break
            
    if c[i]<d[i]:
        print(a, 'está primero en el diccionario')
        break
   
#En caso de que el programa encuentre dos letras iguales, podrán pasar dos
#cosas, 1. si las últimas letras de la palabra son iguales esto querrá decir
#que el código ya examinó todos los índices posibles y no encontró diferencias
#por tanto se examinarán las longitudes de las palabras, la palabra de menor
#longitud irá de primero en el diccionario, si las palabras tienen la misma
#longitud, se concluirá que las palabras son iguales.
#2. se sumará +1 al contador i, para que repita el ciclo con el siguiente
#índice
        
    else:
        if i==Z-1:
            if len(c)>len(d):
                print(b, "está primero en el diccionario")
                
            if len(c)<len(d):
                print(a, 'está primero en el diccionario')
                
            else:
                print("Las palabras están en la misma posición")
            
            break

        while c[i]==d[i]: 
            i+=1
            break
# Out:
# Escriba una palabra: hola
# Escriba otra palabra: holi
# hola está primero en el diccionario

# %% [markdown]
# Escribir un programa que lea una cadena de texto y la imprima como un triángulo. Por ejemplo, si la cadena entrada
# es: "Es una locura odiar a todas las rosas porque una te pinchó: renunciar a todos tus sueños porque uno de ellos no
# se realizó - El Principito"

# %%
a=input('Escriba una frase: ')


a=a.replace(' ','') #Se usa este comando para quitar los espacios 
                    #en la cadena
                    
#Por medio de una serie se va imprimiendo la cadena, de manera que, esta esté
#escalonada, además se centra para que el escalonamiento sea a ambos lados
  
for i in range(0,len(a)):
    print(a[(i-1)**2:i**2].center(80))

# %% [markdown]
# Leer una cadena de texto y organice alfabéticamente cada una de las letras que la componen, repitiendo cada una
# tantas veces como se encuentra. Por ejemplo, la cadena ‘tarea importante’ será ‘aaaeeimnoprrttt’. (Note que no se
# incluyen los espacios).

# %%
a= input(str('Escriba una palabra: '))
a= a.lower()

#se crea una cadena con el orden alfabético

DIC='aábcdeéfghiíjklmnñoópqrstuüvwxyz'

#Se será la lista en donde se guardarán las letras ya ordenadas
C=[] 

#Se ejecutan dos ciclos for, el primero para que vaya letra por letra, el
#segundo evaluará si existe esa letra del primer ciclo índice a índice, de 
#de modo que si hay varias letras repetidas, el segundo ciclo anote una por
#una en la lista C

for i in range(0,len(DIC)):
    for j in range(0,len(a)):
        if DIC[i] in a[j]:
            C.append(a[j])
        
#Se imprime la lista C en forma continua, arrojando la palabra ordenada
            
for i in range(0,len(C)):
    print(C[i],end='')

# %% [markdown]
# Leer una lista de números enteros y enumerar cuantos elementos se repiten exactamente dos veces. Utilizar para tal
# fin el método count() de listas.

# %%
L=[]
a =eval(input('Escriba una lista de números enteros separados por espacios\
 para ser almacenados en una lista: '))


for i in range(min(a),max(a)+1):    #El rango va deacuerdo con el máximo 
    if a.count(i) ==2:              #y el mínimo número que se encuentre en la 
        L.append(i)                 #lista
        print('El número ', i, 'se repite dos veces')
        
        #Si el contador es exactamente 2, el programa imprimirá que se repite
        #dos veces

if len(L)==0:
    print('No hay números repetidos exactamente dos veces')
    
    #Caso contrario que en la lista de números repetidos no haya ningún 
    #elemento, se dirá que no hay elementos que se repitan justamente dos veces

# %% [markdown]
# Leer una lista de números ya ordenados de forma ascendente y verificar
# que dicha lista está ordenada. Luego, leer un número e insertarlo en la
# lista en la posición que le corresponde a dicho número.

# %%
import sys

L = eval(input('Introduzca una lista de números ordenada de forma ascendente'))

cont=0
       
for i in range(0,len(L)-1):             #Se evaluarán todos los índices, siendo
    if L[i]<=L[(i+1)]:                  #que el siguiente sea igual o mayor
        cont=cont                       #de lo contrario el cont dejará de
    else:                               #valer 0 y por tanto arrojará un error
        cont=+1
        
if cont!=0:
    
    sys.exit('la lista no está ordenada de forma ascendente')
        


N= int(input('Introduzca un número'))

for i in range(0,len(L)):
    if N>=L[-1]:                #Si el último dígito de la lista es menor que
                                #que N se adicionará el N a la lista y se
                                #romperá el código. De lo contrario, se irá
        L.append(N)             #iterando por índice hasta que se encuentre un
                                #número que sea menor o igual
        break
    
    if N>L[i]:                  #cumpliéndose esto, se insertará el N en la
        i+=1                    #posición i que se estaba evaluando
    
    if N<=L[i]:
        L.insert(i,N)
        break

print(L)

# %% [markdown]
# Leer una lista y determinar cuál es el segundo elemento más grande de
# dicha lista. No utilice ningún tipo de algoritmo de ordenamiento para
# realizar este ejercicio.

# %%
L =eval(input('Ingrese una lista: '))

#se elimina el elemento más grande introducido en la lista

L.remove(max(L))          

#y se vuelva a encontrar el elemento más grande de la lista, en este caso
#sería el segundo más grande, debido a que el mayor se ha eliminado en el
#paso anterior       
       
print('El segundo elemento más grande de la lista es: ',max(L))

# %% [markdown]
# Leer una matriz cuadrada A, obtener su matriz triangular superior
# asociada U y determinar qué fila de U contiene la mayor cantidad de unos.

# %%
L=eval(input('Ingrese una matriz cuadrada: '))
   

a=-1
#Se creará un ciclo for para cambiar los índices debajo de la diagonal por
#ceros, asimismo se creó un contador para que cada vez que se cambie de columna
#La el índice de la fila también aumente en 1, esto para que se conserve el
#patrón triangular
for i in range(0,len(L)): 
    a+=1                                #i = columnas
    for j in range(1+a,len(L)):         #j = filas
        L[j][i]=0
       
       
#Se agrega una lista vacía que será aquella donde se guardarán el número de
#veces que se repiten el 1 en una fila, y el índice será el homólogo en la
#Lista L
        
L2=[]
       
for columna in range(0,len(L)):
    c=0
    for fila in range(0,len(L)):
        
        if L[columna][fila]==1:
            c+=1
        else:
            continue
    L2.append(c)
    
#Se encuentra el máximo de la lista L2, se encuentra su índice, y la
#infomación de este índice se imprime en la lista L, que es la que posee las
#filas de la matriz diagonal

print('la matriz triangular superior es: ', L)
print('La fila con mayor cantidad de unos es: ', L[L2[max(L2)]])

# %% [markdown]
# Leer una lista e identifique la sublista más larga dentro de dicha
# lista que se encuentra ordenada ascendentemente. Por ejemplo, en la lista
# [5, 6, 5, 1, 2, 6, 9, 2, 4, 1] la mayor sublista ordenada es la
# [1, 2, 6, 9].

# %%
#Se hace un ciclo con try/except para evaluar si lo que se está introduciendo
#es una lista de números enteros

while True:
    try: 
        L=eval(input('Ingrese una lista: '))
        if type(L) == list:
            for i in L:
                if type(i) == int:
                    continue
                else: raise Exception
            break
        else: raise Exception
    except Exception: print('El elemento ingresado debe ser una lista de\
 numeros enteros')
    
#Se agrega un 0 a la lista para corregir error en el rango al momento de la
#interación
    
#Con un ciclo for se evalúa el índice i con el siguiente comparando si el
#segundo es mayor que el primero, sucediendo esto, se agregará a una sublista
#Cuando se llegue a un número que no cumpla esta condición, se agrega una nueva
#sublista vacía y el programa seguirá iterando en busca del mismo patrón en los
#siguientes índices
L.append(0)
s = 0
Lista_S = [[]]
for i in range(0,len(L)-1):
    if L[i] <= L[i+1]:
        Lista_S[s].append(L[i])
    else:
        Lista_S[s].append(L[i])
        s += 1
        Lista_S.append([])
       
LL=[]

for i in Lista_S:
    LL.append(len(i))
    
#Se halla el máximo elemento de la lista LL y será impreso, en caso de 
#encontrar dos elementos con la misma longitud, se imprimirán ambos por medio
#de pop, imprimiendo el primero, eliminándolo y dándole paso al segundo
#para ser evaluado con el comando "max" y ser impreso posteriormente
a= max(LL)
while a in LL:
    
    print(Lista_S.pop(LL.index(max(LL))), 'es la sublista ordenada\
 ascendentemente más larga')
    
    LL.pop(LL.index(max(LL)))

# %% [markdown]
# Hacer un programa que lea una matriz y la rote 90 grados en sentido  antihorario. Imprimir la matriz resultante.
# Repita el mismo ejercicio utilizando el módulo numpy.

# %%
#Se realiza un try except para evitar que el usuario introduzca elementos
#que no sean una matriz, o si bien no tengan números enteros
import numpy as np

while True:
    try:
        L= eval(input('Ingrese una matriz: '))
        if type(L) is list:
            for fila in L:
                if type(fila) is list:
                    for entrada in fila:
                        if type(entrada) is not int:
                            raise Exception
                else:
                    raise Exception
        else:
            raise Exception
        
        for Fila in L:
            if len(Fila) != len(L[0]) :
                raise Exception
        break     
    except:
        print('Debe ser una matriz de numeros enteros con todas sus filas\
 y columnas de igual longitud.')
            


#Con el siguiente comnando se imprimirá la matriz rotada dada una serie
        
print('La matriz rotada 90 grados es : ')
for Columna in range(len(L[0])) :               
    for Fila in range(len(L)) :
        print('{:8}'.format(L[Fila][len(L[0])-Columna-1]),\
end = ' ')
    print()
    
    
a=np.rot90(L)
print('la matriz rotada 90 grados es: ')
print(a)
